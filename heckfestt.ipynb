# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/heckfest/20000741.tif
# /kaggle/input/heckfest/10001271.tif
# /kaggle/input/heckfest/20004597.tif
# /kaggle/input/heckfest/10003221.tif
# /kaggle/input/heckfest/10009123.tif
# /kaggle/input/heckfest/10004733.tif
# /kaggle/input/heckfest/20005142.tif
# /kaggle/input/heckfest/20003828.tif
# /kaggle/input/heckfest/10000737.tif
# /kaggle/input/heckfest/10004997.tif
# /kaggle/input/heckfest/10008404.tif
# /kaggle/input/heckfest/20007033.tif
# /kaggle/input/heckfest/10009514.tif
# /kaggle/input/heckfest/10010045.tif
# /kaggle/input/heckfest/20001237.tif
# /kaggle/input/heckfest/10001480.tif
# /kaggle/input/heckfest/20006917.tif
# /kaggle/input/heckfest/20000169.tif
# /kaggle/input/heckfest/10006923.tif
# /kaggle/input/heckfest/10005430.tif
# /kaggle/input/heckfest/10011436.tif
# /kaggle/input/heckfest/10003270.tif
# /kaggle/input/heckfest/10005500.tif
# /kaggle/input/heckfest/10009717.tif
# /kaggle/input/heckfest/20000448.tif
# /kaggle/input/heckfest/10005044.tif
# ...

# %%
data_csv = pd.read_csv('../input/dementia-label/dataa')

# %%
data_csv
# Out:
#       Unnamed: 0  tar          id
# 0              0  5.0  20000943.0
# 1              1  3.0  10012150.0
# 2              2  2.0  10001662.0
# 3              3  3.0  10005404.0
# 4              4  4.0  20003286.0
# ...          ...  ...         ...
# 3093        3093  5.0  20005413.0
# 3094        3094  5.0  20006668.0
# 3095        3095  2.0  20002368.0
# 3096        3096  4.0  20002195.0
# 3097        3097  3.0  20000782.0
#
# [3098 rows x 3 columns]

# %%
data = data_csv.drop(['Unnamed: 0'], axis=1)

# %%
data
# Out:
#       tar          id
# 0     5.0  20000943.0
# 1     3.0  10012150.0
# 2     2.0  10001662.0
# 3     3.0  10005404.0
# 4     4.0  20003286.0
# ...   ...         ...
# 3093  5.0  20005413.0
# 3094  5.0  20006668.0
# 3095  2.0  20002368.0
# 3096  4.0  20002195.0
# 3097  3.0  20000782.0
#
# [3098 rows x 2 columns]

# %%
target_str = []
for i in range(len(data)):
    target_str.append(str(data['id'][i]))

# %%
for i in range(len(data)):
    target_str[i] = target_str[i].replace('.0', '.tif')

# %%
target_str[:5]
# Out:
# ['20000943.tif',
#  '10012150.tif',
#  '10001662.tif',
#  '10005404.tif',
#  '20003286.tif']

# %%
for i in range(len(data)):
    target_str[i] = '/kaggle/input/heckfest/' + target_str[i]

# %%
target_str[:4]
# Out:
# ['/kaggle/input/heckfest/20000943.tif',
#  '/kaggle/input/heckfest/10012150.tif',
#  '/kaggle/input/heckfest/10001662.tif',
#  '/kaggle/input/heckfest/10005404.tif']

# %%
data['path'] = target_str

# %%
data
# Out:
#       tar          id                                 path
# 0     5.0  20000943.0  /kaggle/input/heckfest/20000943.tif
# 1     3.0  10012150.0  /kaggle/input/heckfest/10012150.tif
# 2     2.0  10001662.0  /kaggle/input/heckfest/10001662.tif
# 3     3.0  10005404.0  /kaggle/input/heckfest/10005404.tif
# 4     4.0  20003286.0  /kaggle/input/heckfest/20003286.tif
# ...   ...         ...                                  ...
# 3093  5.0  20005413.0  /kaggle/input/heckfest/20005413.tif
# 3094  5.0  20006668.0  /kaggle/input/heckfest/20006668.tif
# 3095  2.0  20002368.0  /kaggle/input/heckfest/20002368.tif
# 3096  4.0  20002195.0  /kaggle/input/heckfest/20002195.tif
# 3097  3.0  20000782.0  /kaggle/input/heckfest/20000782.tif
#
# [3098 rows x 3 columns]

# %%
data.to_csv('target_id_path', index=False)
